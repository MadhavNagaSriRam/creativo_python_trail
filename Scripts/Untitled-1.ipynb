# %%
import pandas as pd
# import numpy as np
s=pd.Series([1,4,5,2,6,3])
print(s)
# Out:
# 0    1
# 1    4
# 2    5
# 3    2
# 4    6
# 5    3
# dtype: int64

# %%
import numpy as np

arr=np.array([[1,1,1,1],[2,2,2,2]])

arr1=[[1,1,1,1],[2,2,2,2]]
print(arr1)
print(arr[1][2])
print(arr1[1][2])
arr
# Out:
# [[1, 1, 1, 1], [2, 2, 2, 2]]
# 2
# 2
# array([[1, 1, 1, 1],
#        [2, 2, 2, 2]])

# %%
# s = pd.Series({'a': 1, 'b': 2, 'c': 3})
print(s[0])
# Out:
# 1
# C:\Users\Madhav Naga Sri Ram\AppData\Local\Temp\ipykernel_10100\1576197440.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %%
rd=pd.read_excel("MCCS - 2_Vth sem.xlsx")
# rd.pd.dataframe
# df=pd.DataFrame(rd)
# df.tail(10)
rd
# Out:
#          ADIKAVI NANNAYA UNIVERSITY, RAJAHMUNDRY\t                 Unnamed: 1  \
# 0             B.SC  DEGREE EXAMINATIONS JAN - 2024                        NaN
# 1   ADITYA DEGREE COLLEGE, KAKINADA . CODE NO. 037                        NaN
# 2                                             VSEM                        NaN
# 3                        S.                     NO  R.                     NO
# 4                                                1                         25
# 5                                                2                          1
# 6                                                3                         30
# 7                                                4                          4
# 8                                                5                         21
# 9                                                6                         31
# 10                                               7                         18
# ...

# %%
def myname():
    return "hello"
myname()
# Out:
# 'hello'
